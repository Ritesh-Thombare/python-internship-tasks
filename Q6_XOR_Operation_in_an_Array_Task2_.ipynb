# %% [markdown]
# Q6 XOR Operation in an Array

# %%
class Solution:
    def xorOperation(self, n: int, start: int) -> int:
        result = 0

        for i in range(n):
            value = start + 2 * i
            result ^= value

        return result
